# %% [markdown]
# ### Using the Steam Spy API, will get number of positive and negative comments and Peak Players for the Previous Day
# https://steamspy.com/api.php
#
# ### All time Peak from https://steamplayercount.com

# %%
import pandas as pd
import requests
import json
import time
from bs4 import BeautifulSoup
import numpy as np

# %%
df = pd.read_excel('Data/steam_data_cleaned.xlsx')

# %%
# Column with the IDs
df['Steam_AppID']
# Out:
# 0             10
# 1             20
# 2             30
# 3             40
# 4             50
#           ...
# 11273    2472270
# 11274    2472500
# 11275    2472840
# 11276    2473150
# 11277    2473690
# Name: Steam_AppID, Length: 11278, dtype: int64

# %% [markdown]
# #### Will get the total Reviews and Peak Players of the day before

# %%
# Define function to construct URLs for each App_ID
def get_app_details(app_id):
    url = f"https://steamspy.com/api.php?request=appdetails&appid={app_id}"
    response = requests.get(url)
    data = response.json()
    return data

# Define function to get number of Negative and Posiive comments and the Peak Players yesterday
def get_values(row):
    # Get the App_ID from the dataframe
    app_id = row['Steam_AppID']
    
    # A 1sec delay between requests
    time.sleep(1)
    
    # Get the app details from SteamSpy API for the respective app ID
    app_data = get_app_details(app_id)
    
    # Extract the values from the API
    positive_reviews = app_data.get('positive', None)
    negative_reviews = app_data.get('negative', None)
    Peak_Players_Yesterday = app_data.get('ccu', None) #this will get the peak players on 18/06/2023 (Sunday)
    
    # Return a new pandas Series with the values
    return pd.Series({'Positive_Reviews': positive_reviews, 'Negative_Reviews': negative_reviews, 'Peak_Players_Yesterday': Peak_Players_Yesterday})

# Apply the 'get_values' function to each row of the dataframe
df[['Positive_Reviews', 'Negative_Reviews', 'Peak_Players_Yesterday']] = df.apply(get_values, axis=1)

# %%
# New column for total Reviews
df['Total_reviews'] = df['Positive_Reviews'] + df['Negative_Reviews']

# %%
df.head()
# Out:
#                         Game  Steam_AppID  Minimum_age  Free  \
# 0             Counter-Strike           10            0     0
# 1      Team Fortress Classic           20            0     0
# 2              Day of Defeat           30            0     0
# 3         Deathmatch Classic           40            0     0
# 4  Half-Life: Opposing Force           50            0     0
#
#                                       About_the_Game        Developers  \
# 0  Play the world's number 1 online action game. ...             Valve
# 1  One of the most popular online action games of...             Valve
# 2  Enlist in an intense brand of Axis vs. Allied ...             Valve
# 3  Enjoy fast-paced multiplayer gaming with Death...             Valve
# 4  Return to the Black Mesa Research Facility as ...  Gearbox Software
#
#   Publishers  Windows_Support  Mac_Support  Linux_Support  ...  \
# 0      Valve                1            1              1  ...
# 1      Valve                1            1              1  ...
# 2      Valve                1            1              1  ...
# 3      Valve                1            1              1  ...
# 4      Valve                1            1              1  ...
#
#    DRM_Protection  Discounted_Price Original_Price  \
# 0               0              8.19           8.19
# 1               0              3.99           3.99
# 2               0              3.99           3.99
# 3               0              3.99           3.99
# 4               0              3.99           3.99
#
#                               categories_Description  genres_Description  \
# 0  Multi-player, PvP, Online PvP, Shared/Split Sc...              Action
# 1  Multi-player, PvP, Online PvP, Shared/Split Sc...              Action
# 2             Multi-player, Valve Anti-Cheat enabled              Action
# 3  Multi-player, PvP, Online PvP, Shared/Split Sc...              Action
# 4  Single-player, Multi-player, Valve Anti-Cheat ...              Action
#
#    Is_Subscription  Positive_Reviews  Negative_Reviews  \
# 0                0            214780              5476
# 1                0              6362               980
# 2                0              5629               621
# 3                0              2179               482
# 4                0             17044               864
#
#    Peak_Players_Yesterday Total_reviews
# 0                   11739        220256
# 1                      72          7342
# 2                      94          6250
# 3                       6          2661
# 4                     128         17908
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Will now get the Peak Players of all time

# %%
# Create a new column in the DataFrame to store the values
df['Peak_Players_all_Time'] = None

for index, row in df.iterrows():
    app_id = row['Steam_AppID']
    url = f'https://steamplayercount.com/app/{app_id}'

    # Send a GET request to the URL
    response = requests.get(url)

    # Create a BeautifulSoup object with the response text
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all table elements on the page
    tables = soup.find_all('table')

    # Check if at least one table was found
    if len(tables) > 0:
        # Get the first table
        first_table = tables[0]

        # Find all <span> elements with class "big-text" within the first table
        spans = first_table.find_all('span', class_='big-text')

        # Check if at least three spans were found
        if len(spans) >= 3:
            # Get the third <span> element this cointains the Peak Players
            third_span = spans[2]

            # Extract the text from the <span> element
            text = third_span.get_text()

            # Assign the value to the 'Peak_Players_all_Time' column
            df.at[index, 'Peak_Players_all_Time'] = text
        else:
            print(f"Manually Check App_ID {app_id}.")
    else:
        print(f"Manually Check App_ID {app_id}.")
# Out:
# Manually Check App_ID 12220.
# Manually Check App_ID 255163.
# Manually Check App_ID 256576.
# Manually Check App_ID 256611.
# Manually Check App_ID 345950.
# Manually Check App_ID 360970.
# Manually Check App_ID 400070.
# Manually Check App_ID 429380.
# Manually Check App_ID 544690.
# Manually Check App_ID 620620.
# Manually Check App_ID 636640.
# Manually Check App_ID 643370.
# Manually Check App_ID 668020.
# Manually Check App_ID 668580.
# Manually Check App_ID 687800.
# Manually Check App_ID 717870.
# Manually Check App_ID 733110.
# Manually Check App_ID 743680.
# Manually Check App_ID 756300.
# Manually Check App_ID 756800.
# Manually Check App_ID 772710.
# Manually Check App_ID 772980.
# Manually Check App_ID 781200.
# Manually Check App_ID 789150.
# Manually Check App_ID 789450.
# Manually Check App_ID 790030.
# Manually Check App_ID 790430.
# Manually Check App_ID 821840.
# Manually Check App_ID 823230.
# Manually Check App_ID 843390.
# Manually Check App_ID 871160.
# Manually Check App_ID 871410.
# Manually Check App_ID 871540.
# Manually Check App_ID 878210.
# Manually Check App_ID 879050.
# Manually Check App_ID 896410.
# Manually Check App_ID 897110.
# Manually Check App_ID 912410.
# Manually Check App_ID 954850.
# Manually Check App_ID 955200.
# Manually Check App_ID 986130.
# Manually Check App_ID 1008080.
# Manually Check App_ID 1008860.
# Manually Check App_ID 1011590.
# Manually Check App_ID 1016360.
# Manually Check App_ID 1016950.
# Manually Check App_ID 1020790.
# Manually Check App_ID 1023140.
# Manually Check App_ID 1025560.
# Manually Check App_ID 1025900.
# Manually Check App_ID 1026220.
# Manually Check App_ID 1027570.
# Manually Check App_ID 1027910.
# Manually Check App_ID 1031090.
# Manually Check App_ID 1031460.
# Manually Check App_ID 1046830.
# Manually Check App_ID 1046920.
# Manually Check App_ID 1047560.
# Manually Check App_ID 1047920.
# Manually Check App_ID 1068410.
# Manually Check App_ID 1068460.
# Manually Check App_ID 1068840.
# Manually Check App_ID 1069160.
# Manually Check App_ID 1076120.
# Manually Check App_ID 1084160.
# Manually Check App_ID 1084440.
# Manually Check App_ID 1090100.
# Manually Check App_ID 1097480.
# Manually Check App_ID 1097910.
# Manually Check App_ID 1107390.
# Manually Check App_ID 1108000.
# Manually Check App_ID 1122160.
# Manually Check App_ID 1128860.
# Manually Check App_ID 1177340.
# Manually Check App_ID 1177550.
# Manually Check App_ID 1177980.
# Manually Check App_ID 1179320.
# Manually Check App_ID 1179580.
# Manually Check App_ID 1179890.
# Manually Check App_ID 1180200.
# Manually Check App_ID 1192810.
# Manually Check App_ID 1194250.
# Manually Check App_ID 1194810.
# Manually Check App_ID 1217090.
# Manually Check App_ID 1217410.
# Manually Check App_ID 1217950.
# Manually Check App_ID 1217990.
# Manually Check App_ID 1229240.
# Manually Check App_ID 1230000.
# Manually Check App_ID 1230170.
# Manually Check App_ID 1230530.
# Manually Check App_ID 1231990.
# Manually Check App_ID 1234040.
# Manually Check App_ID 1244600.
# Manually Check App_ID 1244610.
# Manually Check App_ID 1244620.
# Manually Check App_ID 1245250.
# Manually Check App_ID 1245440.
# Manually Check App_ID 1245560.
# Manually Check App_ID 1245960.
# Manually Check App_ID 1260320.
# Manually Check App_ID 1260790.
# Manually Check App_ID 1261220.
# Manually Check App_ID 1261430.
# Manually Check App_ID 1268750.
# Manually Check App_ID 1272840.
# Manually Check App_ID 1273000.
# Manually Check App_ID 1273480.
# Manually Check App_ID 1273830.
# Manually Check App_ID 1274230.
# Manually Check App_ID 1274830.
# Manually Check App_ID 1275370.
# Manually Check App_ID 1275550.
# Manually Check App_ID 1276800.
# Manually Check App_ID 1290330.
# Manually Check App_ID 1290760.
# Manually Check App_ID 1290980.
# Manually Check App_ID 1292500.
# Manually Check App_ID 1293300.
# Manually Check App_ID 1293660.
# Manually Check App_ID 1294810.
# Manually Check App_ID 1295730.
# Manually Check App_ID 1296450.
# Manually Check App_ID 1296490.
# Manually Check App_ID 1304930.
# Manually Check App_ID 1329880.
# Manually Check App_ID 1330360.
# Manually Check App_ID 1330430.
# Manually Check App_ID 1331170.
# Manually Check App_ID 1331510.
# Manually Check App_ID 1331550.
# Manually Check App_ID 1342690.
# Manually Check App_ID 1343340.
# Manually Check App_ID 1345780.
# Manually Check App_ID 1345890.
# Manually Check App_ID 1346480.
# Manually Check App_ID 1347310.
# Manually Check App_ID 1347950.
# Manually Check App_ID 1349460.
# Manually Check App_ID 1360880.
# Manually Check App_ID 1361460.
# Manually Check App_ID 1362000.
# Manually Check App_ID 1362010.
# Manually Check App_ID 1362120.
# Manually Check App_ID 1362470.
# Manually Check App_ID 1366650.
# Manually Check App_ID 1368130.
# Manually Check App_ID 1375020.
# Manually Check App_ID 1375230.
# Manually Check App_ID 1375290.
# Manually Check App_ID 1375820.
# Manually Check App_ID 1375900.
# Manually Check App_ID 1376030.
# Manually Check App_ID 1376760.
# Manually Check App_ID 1376910.
# Manually Check App_ID 1376960.
# Manually Check App_ID 1377050.
# Manually Check App_ID 1383140.
# Manually Check App_ID 1386630.
# Manually Check App_ID 1389140.
# Manually Check App_ID 1389520.
# Manually Check App_ID 1389840.
# Manually Check App_ID 1390070.
# Manually Check App_ID 1390870.
# Manually Check App_ID 1390960.
# Manually Check App_ID 1398910.
# Manually Check App_ID 1401020.
# Manually Check App_ID 1404100.
# Manually Check App_ID 1404520.
# Manually Check App_ID 1404710.
# Manually Check App_ID 1404770.
# Manually Check App_ID 1404840.
# Manually Check App_ID 1405050.
# Manually Check App_ID 1405500.
# Manually Check App_ID 1405530.
# Manually Check App_ID 1405930.
# Manually Check App_ID 1406260.
# Manually Check App_ID 1406810.
# Manually Check App_ID 1407760.
# Manually Check App_ID 1418390.
# Manually Check App_ID 1419850.
# Manually Check App_ID 1420350.
# Manually Check App_ID 1421130.
# Manually Check App_ID 1421350.
# Manually Check App_ID 1421490.
# Manually Check App_ID 1421730.
# Manually Check App_ID 1422580.
# Manually Check App_ID 1424600.
# Manually Check App_ID 1433140.
# Manually Check App_ID 1434260.
# Manually Check App_ID 1441040.
# Manually Check App_ID 1441270.
# Manually Check App_ID 1446310.
# Manually Check App_ID 1447970.
# Manually Check App_ID 1448110.
# Manually Check App_ID 1448130.
# Manually Check App_ID 1448150.
# Manually Check App_ID 1448160.
# Manually Check App_ID 1448170.
# Manually Check App_ID 1448350.
# Manually Check App_ID 1448440.
# Manually Check App_ID 1448820.
# Manually Check App_ID 1451470.
# Manually Check App_ID 1458090.
# Manually Check App_ID 1458140.
# Manually Check App_ID 1458950.
# Manually Check App_ID 1459000.
# Manually Check App_ID 1459260.
# Manually Check App_ID 1459650.
# Manually Check App_ID 1459890.
# Manually Check App_ID 1459990.
# Manually Check App_ID 1465550.
# Manually Check App_ID 1468400.
# Manually Check App_ID 1474160.
# Manually Check App_ID 1474480.
# Manually Check App_ID 1474770.
# Manually Check App_ID 1475030.
# Manually Check App_ID 1475120.
# Manually Check App_ID 1475330.
# Manually Check App_ID 1475450.
# Manually Check App_ID 1475520.
# Manually Check App_ID 1475550.
# Manually Check App_ID 1475800.
# Manually Check App_ID 1475840.
# Manually Check App_ID 1476400.
# Manually Check App_ID 1477070.
# Manually Check App_ID 1477170.
# Manually Check App_ID 1481860.
# Manually Check App_ID 1489590.
# Manually Check App_ID 1489780.
# Manually Check App_ID 1490450.
# Manually Check App_ID 1490590.
# Manually Check App_ID 1490930.
# Manually Check App_ID 1491000.
# Manually Check App_ID 1491500.
# Manually Check App_ID 1491670.
# Manually Check App_ID 1491920.
# Manually Check App_ID 1492100.
# Manually Check App_ID 1492120.
# Manually Check App_ID 1492150.
# Manually Check App_ID 1492320.
# Manually Check App_ID 1492330.
# Manually Check App_ID 1492350.
# Manually Check App_ID 1504840.
# Manually Check App_ID 1505230.
# Manually Check App_ID 1505830.
# Manually Check App_ID 1505940.
# Manually Check App_ID 1506250.
# Manually Check App_ID 1506440.
# Manually Check App_ID 1506530.
# Manually Check App_ID 1506680.
# Manually Check App_ID 1506930.
# Manually Check App_ID 1566200.
# Manually Check App_ID 1566450.
# Manually Check App_ID 1566550.
# Manually Check App_ID 1566670.
# Manually Check App_ID 1566880.
# Manually Check App_ID 1567000.
# Manually Check App_ID 1567020.
# Manually Check App_ID 1567030.
# Manually Check App_ID 1567100.
# Manually Check App_ID 1568130.
# Manually Check App_ID 1568970.
# Manually Check App_ID 1569290.
# Manually Check App_ID 1573090.
# Manually Check App_ID 1574310.
# Manually Check App_ID 1574870.
# Manually Check App_ID 1575450.
# Manually Check App_ID 1575680.
# Manually Check App_ID 1576280.
# Manually Check App_ID 1576560.
# Manually Check App_ID 1577250.
# Manually Check App_ID 1581480.
# Manually Check App_ID 1581770.
# Manually Check App_ID 1581790.
# Manually Check App_ID 1594880.
# Manually Check App_ID 1594960.
# Manually Check App_ID 1595230.
# Manually Check App_ID 1595400.
# Manually Check App_ID 1595620.
# Manually Check App_ID 1595760.
# Manually Check App_ID 1595770.
# Manually Check App_ID 1595900.
# Manually Check App_ID 1596010.
# Manually Check App_ID 1596030.
# Manually Check App_ID 1596150.
# Manually Check App_ID 1596170.
# Manually Check App_ID 1596360.
# Manually Check App_ID 1596730.
# Manually Check App_ID 1597460.
# Manually Check App_ID 1602560.
# Manually Check App_ID 1610990.
# Manually Check App_ID 1611290.
# Manually Check App_ID 1611810.
# Manually Check App_ID 1611840.
# Manually Check App_ID 1611960.
# Manually Check App_ID 1611980.
# Manually Check App_ID 1612020.
# Manually Check App_ID 1612100.
# Manually Check App_ID 1612130.
# Manually Check App_ID 1612230.
# Manually Check App_ID 1612370.
# Manually Check App_ID 1612500.
# Manually Check App_ID 1612520.
# Manually Check App_ID 1612730.
# Manually Check App_ID 1612900.
# Manually Check App_ID 1612990.
# Manually Check App_ID 1613140.
# Manually Check App_ID 1613290.
# Manually Check App_ID 1613320.
# Manually Check App_ID 1613380.
# Manually Check App_ID 1613400.
# Manually Check App_ID 1613470.
# Manually Check App_ID 1613500.
# Manually Check App_ID 1613520.
# Manually Check App_ID 1613540.
# Manually Check App_ID 1613580.
# Manually Check App_ID 1613620.
# Manually Check App_ID 1613670.
# Manually Check App_ID 1613740.
# Manually Check App_ID 1613760.
# Manually Check App_ID 1613800.
# Manually Check App_ID 1627570.
# Manually Check App_ID 1628260.
# Manually Check App_ID 1628300.
# Manually Check App_ID 1628620.
# Manually Check App_ID 1628650.
# Manually Check App_ID 1628730.
# Manually Check App_ID 1628850.
# Manually Check App_ID 1628890.
# Manually Check App_ID 1629130.
# Manually Check App_ID 1629480.
# Manually Check App_ID 1629520.
# Manually Check App_ID 1629690.
# Manually Check App_ID 1629740.
# Manually Check App_ID 1629830.
# Manually Check App_ID 1629910.
# Manually Check App_ID 1629940.
# Manually Check App_ID 1630010.
# Manually Check App_ID 1630110.
# Manually Check App_ID 1630270.
# Manually Check App_ID 1630310.
# Manually Check App_ID 1630370.
# Manually Check App_ID 1630440.
# Manually Check App_ID 1630450.
# Manually Check App_ID 1630520.
# Manually Check App_ID 1630810.
# Manually Check App_ID 1630930.
# Manually Check App_ID 1639700.
# Manually Check App_ID 1643100.
# Manually Check App_ID 1643310.
# Manually Check App_ID 1643520.
# Manually Check App_ID 1643800.
# Manually Check App_ID 1644230.
# Manually Check App_ID 1644320.
# Manually Check App_ID 1644500.
# Manually Check App_ID 1644830.
# Manually Check App_ID 1644940.
# Manually Check App_ID 1657950.
# Manually Check App_ID 1658040.
# Manually Check App_ID 1658090.
# Manually Check App_ID 1658390.
# Manually Check App_ID 1658450.
# Manually Check App_ID 1658750.
# Manually Check App_ID 1658960.
# Manually Check App_ID 1659140.
# Manually Check App_ID 1659300.
# Manually Check App_ID 1659360.
# Manually Check App_ID 1659410.
# Manually Check App_ID 1659420.
# Manually Check App_ID 1659500.
# Manually Check App_ID 1659610.
# Manually Check App_ID 1659790.
# Manually Check App_ID 1660080.
# Manually Check App_ID 1660090.
# Manually Check App_ID 1660150.
# Manually Check App_ID 1660170.
# Manually Check App_ID 1660220.
# Manually Check App_ID 1660230.
# Manually Check App_ID 1660260.
# Manually Check App_ID 1660340.
# Manually Check App_ID 1660580.
# Manually Check App_ID 1660680.
# Manually Check App_ID 1662300.
# Manually Check App_ID 1663640.
# Manually Check App_ID 1669000.
# Manually Check App_ID 1669180.
# Manually Check App_ID 1671720.
# Manually Check App_ID 1672110.
# Manually Check App_ID 1672160.
# Manually Check App_ID 1672310.
# Manually Check App_ID 1672320.
# Manually Check App_ID 1672360.
# Manually Check App_ID 1672610.
# Manually Check App_ID 1672650.
# Manually Check App_ID 1672830.
# Manually Check App_ID 1672880.
# Manually Check App_ID 1673090.
# Manually Check App_ID 1673220.
# Manually Check App_ID 1673460.
# Manually Check App_ID 1673510.
# Manually Check App_ID 1673580.
# Manually Check App_ID 1673650.
# Manually Check App_ID 1674120.
# Manually Check App_ID 1674300.
# Manually Check App_ID 1674420.
# Manually Check App_ID 1674550.
# Manually Check App_ID 1684620.
# Manually Check App_ID 1684650.
# Manually Check App_ID 1684750.
# Manually Check App_ID 1684850.
# Manually Check App_ID 1684880.
# Manually Check App_ID 1684930.
# Manually Check App_ID 1684990.
# Manually Check App_ID 1685000.
# Manually Check App_ID 1685020.
# Manually Check App_ID 1685120.
# Manually Check App_ID 1685550.
# Manually Check App_ID 1685590.
# Manually Check App_ID 1685660.
# Manually Check App_ID 1685730.
# Manually Check App_ID 1685760.
# Manually Check App_ID 1685930.
# Manually Check App_ID 1685970.
# Manually Check App_ID 1686010.
# Manually Check App_ID 1686070.
# Manually Check App_ID 1686140.
# Manually Check App_ID 1686800.
# Manually Check App_ID 1690560.
# Manually Check App_ID 1695270.
# Manually Check App_ID 1695460.
# Manually Check App_ID 1695570.
# Manually Check App_ID 1695650.
# Manually Check App_ID 1695960.
# Manually Check App_ID 1695970.
# Manually Check App_ID 1696030.
# Manually Check App_ID 1696130.
# Manually Check App_ID 1696300.
# Manually Check App_ID 1696630.
# Manually Check App_ID 1696740.
# Manually Check App_ID 1696900.
# Manually Check App_ID 1696960.
# Manually Check App_ID 1697040.
# Manually Check App_ID 1697060.
# Manually Check App_ID 1697110.
# Manually Check App_ID 1697180.
# Manually Check App_ID 1697250.
# Manually Check App_ID 1704150.
# Manually Check App_ID 1704170.
# Manually Check App_ID 1704180.
# Manually Check App_ID 1704250.
# Manually Check App_ID 1704260.
# Manually Check App_ID 1708850.
# Manually Check App_ID 1710540.
# Manually Check App_ID 1713030.
# Manually Check App_ID 1713050.
# Manually Check App_ID 1713070.
# Manually Check App_ID 1713100.
# Manually Check App_ID 1713140.
# Manually Check App_ID 1713160.
# Manually Check App_ID 1713190.
# Manually Check App_ID 1713340.
# Manually Check App_ID 1713410.
# Manually Check App_ID 1713470.
# Manually Check App_ID 1713510.
# Manually Check App_ID 1713550.
# Manually Check App_ID 1713680.
# Manually Check App_ID 1713710.
# Manually Check App_ID 1713730.
# Manually Check App_ID 1713750.
# Manually Check App_ID 1713830.
# Manually Check App_ID 1713860.
# Manually Check App_ID 1713880.
# Manually Check App_ID 1713970.
# Manually Check App_ID 1713990.
# Manually Check App_ID 1714020.
# Manually Check App_ID 1714070.
# Manually Check App_ID 1714090.
# Manually Check App_ID 1714100.
# Manually Check App_ID 1714180.
# Manually Check App_ID 1714240.
# Manually Check App_ID 1714250.
# Manually Check App_ID 1714280.
# Manually Check App_ID 1714310.
# Manually Check App_ID 1714370.
# Manually Check App_ID 1714390.
# Manually Check App_ID 1714430.
# Manually Check App_ID 1714500.
# Manually Check App_ID 1714650.
# Manually Check App_ID 1714680.
# Manually Check App_ID 1714710.
# Manually Check App_ID 1714730.
# Manually Check App_ID 1714760.
# Manually Check App_ID 1714920.
# Manually Check App_ID 1714970.
# Manually Check App_ID 1715000.
# Manually Check App_ID 1715040.
# Manually Check App_ID 1715110.
# Manually Check App_ID 1715160.
# Manually Check App_ID 1715190.
# Manually Check App_ID 1715270.
# Manually Check App_ID 1715330.
# Manually Check App_ID 1715370.
# Manually Check App_ID 1715390.
# Manually Check App_ID 1715470.
# Manually Check App_ID 1715490.
# Manually Check App_ID 1715500.
# Manually Check App_ID 1715580.
# Manually Check App_ID 1715660.
# Manually Check App_ID 1715670.
# Manually Check App_ID 1726850.
# Manually Check App_ID 1726860.
# Manually Check App_ID 1726970.
# Manually Check App_ID 1727020.
# Manually Check App_ID 1727090.
# Manually Check App_ID 1727130.
# Manually Check App_ID 1727140.
# Manually Check App_ID 1727200.
# Manually Check App_ID 1727210.
# Manually Check App_ID 1727220.
# Manually Check App_ID 1727250.
# Manually Check App_ID 1727260.
# Manually Check App_ID 1727270.
# Manually Check App_ID 1727310.
# Manually Check App_ID 1727320.
# Manually Check App_ID 1727340.
# Manually Check App_ID 1727400.
# Manually Check App_ID 1727450.
# Manually Check App_ID 1727550.
# Manually Check App_ID 1727600.
# Manually Check App_ID 1727620.
# Manually Check App_ID 1727720.
# Manually Check App_ID 1727750.
# Manually Check App_ID 1727760.
# Manually Check App_ID 1727790.
# Manually Check App_ID 1727840.
# Manually Check App_ID 1727880.
# Manually Check App_ID 1727910.
# Manually Check App_ID 1727990.
# Manually Check App_ID 1728010.
# Manually Check App_ID 1728020.
# Manually Check App_ID 1728110.
# Manually Check App_ID 1728120.
# Manually Check App_ID 1728160.
# Manually Check App_ID 1728170.
# Manually Check App_ID 1728180.
# Manually Check App_ID 1728290.
# Manually Check App_ID 1728310.
# Manually Check App_ID 1728390.
# Manually Check App_ID 1728410.
# Manually Check App_ID 1728430.
# Manually Check App_ID 1728500.
# Manually Check App_ID 1728520.
# Manually Check App_ID 1728560.
# Manually Check App_ID 1728590.
# Manually Check App_ID 1728640.
# Manually Check App_ID 1728700.
# Manually Check App_ID 1728750.
# Manually Check App_ID 1728850.
# Manually Check App_ID 1728960.
# Manually Check App_ID 1729060.
# Manually Check App_ID 1729070.
# Manually Check App_ID 1729100.
# Manually Check App_ID 1729120.
# Manually Check App_ID 1729150.
# Manually Check App_ID 1729160.
# Manually Check App_ID 1729210.
# Manually Check App_ID 1729250.
# Manually Check App_ID 1729260.
# Manually Check App_ID 1729290.
# Manually Check App_ID 1729370.
# Manually Check App_ID 1729660.
# Manually Check App_ID 1729730.
# Manually Check App_ID 1729760.
# Manually Check App_ID 1740870.
# Manually Check App_ID 1740920.
# Manually Check App_ID 1740930.
# Manually Check App_ID 1740950.
# Manually Check App_ID 1740990.
# Manually Check App_ID 1741030.
# Manually Check App_ID 1741080.
# Manually Check App_ID 1741200.
# Manually Check App_ID 1741220.
# Manually Check App_ID 1741230.
# Manually Check App_ID 1741260.
# Manually Check App_ID 1741300.
# Manually Check App_ID 1741400.
# Manually Check App_ID 1741420.
# Manually Check App_ID 1741440.
# Manually Check App_ID 1741480.
# Manually Check App_ID 1741490.
# Manually Check App_ID 1741500.
# Manually Check App_ID 1741510.
# Manually Check App_ID 1741520.
# Manually Check App_ID 1741550.
# Manually Check App_ID 1741620.
# Manually Check App_ID 1741630.
# Manually Check App_ID 1741650.
# Manually Check App_ID 1741660.
# Manually Check App_ID 1741730.
# Manually Check App_ID 1741960.
# Manually Check App_ID 1742010.
# Manually Check App_ID 1742020.
# Manually Check App_ID 1742060.
# Manually Check App_ID 1742080.
# Manually Check App_ID 1742160.
# Manually Check App_ID 1742170.
# Manually Check App_ID 1742210.
# Manually Check App_ID 1742240.
# Manually Check App_ID 1742290.
# Manually Check App_ID 1742330.
# Manually Check App_ID 1742340.
# Manually Check App_ID 1742350.
# Manually Check App_ID 1742400.
# Manually Check App_ID 1742480.
# Manually Check App_ID 1742500.
# Manually Check App_ID 1742510.
# Manually Check App_ID 1742560.
# Manually Check App_ID 1742600.
# Manually Check App_ID 1742620.
# Manually Check App_ID 1742690.
# Manually Check App_ID 1742720.
# Manually Check App_ID 1742730.
# Manually Check App_ID 1742740.
# Manually Check App_ID 1742750.
# Manually Check App_ID 1742800.
# Manually Check App_ID 1742880.
# Manually Check App_ID 1742900.
# Manually Check App_ID 1742910.
# Manually Check App_ID 1742930.
# Manually Check App_ID 1742940.
# Manually Check App_ID 1742970.
# Manually Check App_ID 1743010.
# Manually Check App_ID 1743050.
# Manually Check App_ID 1743060.
# Manually Check App_ID 1743110.
# Manually Check App_ID 1743120.
# Manually Check App_ID 1743140.
# Manually Check App_ID 1743180.
# Manually Check App_ID 1743220.
# Manually Check App_ID 1743230.
# Manually Check App_ID 1743280.
# Manually Check App_ID 1743350.
# Manually Check App_ID 1743380.
# Manually Check App_ID 1743470.
# Manually Check App_ID 1743530.
# Manually Check App_ID 1743610.
# Manually Check App_ID 1743650.
# Manually Check App_ID 1743660.
# Manually Check App_ID 1743770.
# Manually Check App_ID 1743810.
# Manually Check App_ID 1743830.
# Manually Check App_ID 1791440.
# Manually Check App_ID 1791510.
# Manually Check App_ID 1791630.
# Manually Check App_ID 1791640.
# Manually Check App_ID 1791650.
# Manually Check App_ID 1791710.
# Manually Check App_ID 1791820.
# Manually Check App_ID 1791990.
# Manually Check App_ID 1792070.
# Manually Check App_ID 1792170.
# Manually Check App_ID 1792230.
# Manually Check App_ID 1792270.
# Manually Check App_ID 1792280.
# Manually Check App_ID 1792290.
# Manually Check App_ID 1792300.
# Manually Check App_ID 1792380.
# Manually Check App_ID 1792390.
# Manually Check App_ID 1792520.
# Manually Check App_ID 1792530.
# Manually Check App_ID 1792700.
# Manually Check App_ID 1792730.
# Manually Check App_ID 1792740.
# Manually Check App_ID 1792770.
# Manually Check App_ID 1792790.
# Manually Check App_ID 1792810.
# Manually Check App_ID 1792860.
# Manually Check App_ID 1792970.
# Manually Check App_ID 1793000.
# Manually Check App_ID 1793030.
# Manually Check App_ID 1793040.
# Manually Check App_ID 1793060.
# Manually Check App_ID 1793070.
# Manually Check App_ID 1793080.
# Manually Check App_ID 1793090.
# Manually Check App_ID 1793110.
# Manually Check App_ID 1793120.
# Manually Check App_ID 1793150.
# Manually Check App_ID 1793170.
# Manually Check App_ID 1793190.
# Manually Check App_ID 1793220.
# Manually Check App_ID 1793240.
# Manually Check App_ID 1793250.
# Manually Check App_ID 1793320.
# Manually Check App_ID 1793340.
# Manually Check App_ID 1793360.
# Manually Check App_ID 1793370.
# Manually Check App_ID 1793400.
# Manually Check App_ID 1793420.
# Manually Check App_ID 1793560.
# Manually Check App_ID 1793660.
# Manually Check App_ID 1793680.
# Manually Check App_ID 1793780.
# Manually Check App_ID 1793800.
# Manually Check App_ID 1793900.
# Manually Check App_ID 1793910.
# Manually Check App_ID 1793960.
# Manually Check App_ID 1793970.
# Manually Check App_ID 1794020.
# Manually Check App_ID 1794120.
# Manually Check App_ID 1794160.
# Manually Check App_ID 1794190.
# Manually Check App_ID 1794220.
# Manually Check App_ID 1794250.
# Manually Check App_ID 1794320.
# Manually Check App_ID 1794330.
# Manually Check App_ID 1797630.
# Manually Check App_ID 1804550.
# Manually Check App_ID 1804570.
# Manually Check App_ID 1804580.
# Manually Check App_ID 1804590.
# Manually Check App_ID 1804600.
# Manually Check App_ID 1804610.
# Manually Check App_ID 1804640.
# Manually Check App_ID 1804710.
# Manually Check App_ID 1804720.
# Manually Check App_ID 1804730.
# Manually Check App_ID 1804740.
# Manually Check App_ID 1804760.
# Manually Check App_ID 1804820.
# Manually Check App_ID 1804880.
# Manually Check App_ID 1804890.
# Manually Check App_ID 1804900.
# Manually Check App_ID 1804980.
# Manually Check App_ID 1804990.
# Manually Check App_ID 1805020.
# Manually Check App_ID 1805070.
# Manually Check App_ID 1805080.
# Manually Check App_ID 1805140.
# Manually Check App_ID 1805150.
# Manually Check App_ID 1805170.
# Manually Check App_ID 1805210.
# Manually Check App_ID 1805220.
# Manually Check App_ID 1805230.
# Manually Check App_ID 1805270.
# Manually Check App_ID 1805310.
# Manually Check App_ID 1805340.
# Manually Check App_ID 1805390.
# Manually Check App_ID 1805480.
# Manually Check App_ID 1805490.
# Manually Check App_ID 1805500.
# Manually Check App_ID 1805510.
# Manually Check App_ID 1805550.
# Manually Check App_ID 1805560.
# Manually Check App_ID 1805610.
# Manually Check App_ID 1805650.
# Manually Check App_ID 1805670.
# Manually Check App_ID 1805680.
# Manually Check App_ID 1805700.
# Manually Check App_ID 1805720.
# Manually Check App_ID 1805770.
# Manually Check App_ID 1805920.
# Manually Check App_ID 1805960.
# Manually Check App_ID 1805970.
# Manually Check App_ID 1805980.
# Manually Check App_ID 1805990.
# Manually Check App_ID 1806000.
# Manually Check App_ID 1806070.
# Manually Check App_ID 1806110.
# Manually Check App_ID 1806190.
# Manually Check App_ID 1806350.
# Manually Check App_ID 1806380.
# Manually Check App_ID 1806400.
# Manually Check App_ID 1806410.
# Manually Check App_ID 1806430.
# Manually Check App_ID 1806440.
# Manually Check App_ID 1806460.
# Manually Check App_ID 1806480.
# Manually Check App_ID 1806570.
# Manually Check App_ID 1806580.
# Manually Check App_ID 1806640.
# Manually Check App_ID 1806690.
# Manually Check App_ID 1806830.
# Manually Check App_ID 1806860.
# Manually Check App_ID 1817190.
# Manually Check App_ID 1888930.
# Manually Check App_ID 1904610.
# Manually Check App_ID 1904640.
# Manually Check App_ID 1904650.
# Manually Check App_ID 1904680.
# Manually Check App_ID 1904690.
# Manually Check App_ID 1904730.
# Manually Check App_ID 1904790.
# Manually Check App_ID 1904800.
# Manually Check App_ID 1904820.
# Manually Check App_ID 1904860.
# Manually Check App_ID 1904890.
# Manually Check App_ID 1904980.
# Manually Check App_ID 1905000.
# Manually Check App_ID 1905020.
# Manually Check App_ID 1905050.
# Manually Check App_ID 1905060.
# Manually Check App_ID 1905080.
# Manually Check App_ID 1905110.
# Manually Check App_ID 1905150.
# Manually Check App_ID 1905180.
# Manually Check App_ID 1905210.
# Manually Check App_ID 1905220.
# Manually Check App_ID 1905230.
# Manually Check App_ID 1905260.
# Manually Check App_ID 1905270.
# Manually Check App_ID 1905310.
# Manually Check App_ID 1905350.
# Manually Check App_ID 1905420.
# Manually Check App_ID 1905430.
# Manually Check App_ID 1905470.
# Manually Check App_ID 1905510.
# Manually Check App_ID 1905540.
# Manually Check App_ID 1905550.
# Manually Check App_ID 1905560.
# Manually Check App_ID 1905640.
# Manually Check App_ID 1905670.
# Manually Check App_ID 1905700.
# Manually Check App_ID 1905780.
# Manually Check App_ID 1905810.
# Manually Check App_ID 1905900.
# Manually Check App_ID 1905910.
# Manually Check App_ID 1905920.
# Manually Check App_ID 1905940.
# Manually Check App_ID 1905950.
# Manually Check App_ID 1905960.
# Manually Check App_ID 1905980.
# Manually Check App_ID 1906000.
# Manually Check App_ID 1906020.
# Manually Check App_ID 1906050.
# Manually Check App_ID 1906060.
# Manually Check App_ID 1906070.
# Manually Check App_ID 1906100.
# Manually Check App_ID 1906110.
# Manually Check App_ID 1906130.
# Manually Check App_ID 1906140.
# Manually Check App_ID 1906150.
# Manually Check App_ID 1906160.
# Manually Check App_ID 1906180.
# Manually Check App_ID 1906220.
# Manually Check App_ID 1906250.
# Manually Check App_ID 1906320.
# Manually Check App_ID 1906350.
# Manually Check App_ID 1906400.
# Manually Check App_ID 1906410.
# Manually Check App_ID 1906510.
# Manually Check App_ID 1906540.
# Manually Check App_ID 1906570.
# Manually Check App_ID 1906590.
# Manually Check App_ID 1906640.
# Manually Check App_ID 1906660.
# Manually Check App_ID 1906670.
# Manually Check App_ID 1906680.
# Manually Check App_ID 1906750.
# Manually Check App_ID 1906800.
# Manually Check App_ID 1906860.
# Manually Check App_ID 1906870.
# Manually Check App_ID 1906880.
# Manually Check App_ID 1906890.
# Manually Check App_ID 1906910.
# Manually Check App_ID 1906950.
# Manually Check App_ID 1906980.
# Manually Check App_ID 1907000.
# Manually Check App_ID 1907020.
# Manually Check App_ID 1907060.
# Manually Check App_ID 1907070.
# Manually Check App_ID 1907120.
# Manually Check App_ID 1907140.
# Manually Check App_ID 1907150.
# Manually Check App_ID 1907170.
# Manually Check App_ID 1907180.
# Manually Check App_ID 1907220.
# Manually Check App_ID 1907230.
# Manually Check App_ID 1907280.
# Manually Check App_ID 1907290.
# Manually Check App_ID 1907350.
# Manually Check App_ID 1907380.
# Manually Check App_ID 1907420.
# Manually Check App_ID 1919910.
# Manually Check App_ID 1919920.
# Manually Check App_ID 1919960.
# Manually Check App_ID 1920010.
# Manually Check App_ID 1920040.
# Manually Check App_ID 1920100.
# Manually Check App_ID 1920120.
# Manually Check App_ID 1920200.
# Manually Check App_ID 1920210.
# Manually Check App_ID 1920270.
# Manually Check App_ID 1920320.
# Manually Check App_ID 1920390.
# Manually Check App_ID 1920400.
# Manually Check App_ID 1920410.
# Manually Check App_ID 1920420.
# Manually Check App_ID 1920440.
# Manually Check App_ID 1920450.
# Manually Check App_ID 1920460.
# Manually Check App_ID 1920480.
# Manually Check App_ID 1920490.
# Manually Check App_ID 1920500.
# Manually Check App_ID 1920510.
# Manually Check App_ID 1920520.
# Manually Check App_ID 1920540.
# Manually Check App_ID 1920550.
# Manually Check App_ID 1920580.
# Manually Check App_ID 1920650.
# Manually Check App_ID 1920660.
# Manually Check App_ID 1920700.
# Manually Check App_ID 1920710.
# Manually Check App_ID 1920720.
# Manually Check App_ID 1920760.
# Manually Check App_ID 1920780.
# Manually Check App_ID 1920790.
# Manually Check App_ID 1920800.
# Manually Check App_ID 1920810.
# Manually Check App_ID 1920820.
# Manually Check App_ID 1920850.
# Manually Check App_ID 1920940.
# Manually Check App_ID 1920950.
# Manually Check App_ID 1921040.
# Manually Check App_ID 1921080.
# Manually Check App_ID 1921090.
# Manually Check App_ID 1921120.
# Manually Check App_ID 1921130.
# Manually Check App_ID 1921140.
# Manually Check App_ID 1921160.
# Manually Check App_ID 1921170.
# Manually Check App_ID 1921180.
# Manually Check App_ID 1921200.
# Manually Check App_ID 1921210.
# Manually Check App_ID 1921240.
# Manually Check App_ID 1921250.
# Manually Check App_ID 1921270.
# Manually Check App_ID 1921330.
# Manually Check App_ID 1921340.
# Manually Check App_ID 1921390.
# Manually Check App_ID 1921400.
# Manually Check App_ID 1921450.
# Manually Check App_ID 1921460.
# Manually Check App_ID 1921480.
# Manually Check App_ID 1921500.
# Manually Check App_ID 1921510.
# Manually Check App_ID 1921530.
# Manually Check App_ID 1921550.
# Manually Check App_ID 1921560.
# Manually Check App_ID 1921570.
# Manually Check App_ID 1921600.
# Manually Check App_ID 1921610.
# Manually Check App_ID 1921660.
# Manually Check App_ID 1921680.
# Manually Check App_ID 1921740.
# Manually Check App_ID 1921760.
# Manually Check App_ID 1921770.
# Manually Check App_ID 1921780.
# Manually Check App_ID 1921820.
# Manually Check App_ID 1921840.
# Manually Check App_ID 1921850.
# Manually Check App_ID 1921880.
# Manually Check App_ID 1921900.
# Manually Check App_ID 1921940.
# Manually Check App_ID 1921950.
# Manually Check App_ID 1921980.
# Manually Check App_ID 1922000.
# Manually Check App_ID 1922010.
# Manually Check App_ID 1922030.
# Manually Check App_ID 1922060.
# Manually Check App_ID 1922070.
# Manually Check App_ID 1922100.
# Manually Check App_ID 1922120.
# Manually Check App_ID 1922130.
# Manually Check App_ID 1922140.
# Manually Check App_ID 1922150.
# Manually Check App_ID 1922160.
# Manually Check App_ID 1922180.
# Manually Check App_ID 1922190.
# Manually Check App_ID 1922200.
# Manually Check App_ID 1922210.
# Manually Check App_ID 1922320.
# Manually Check App_ID 1922340.
# Manually Check App_ID 1922360.
# Manually Check App_ID 1922530.
# Manually Check App_ID 1922540.
# Manually Check App_ID 1922550.
# Manually Check App_ID 1922560.
# Manually Check App_ID 1922580.
# Manually Check App_ID 1922610.
# Manually Check App_ID 1922620.
# Manually Check App_ID 1924360.
# Manually Check App_ID 1933180.
# Manually Check App_ID 1936740.
# Manually Check App_ID 1936840.
# Manually Check App_ID 1936860.
# Manually Check App_ID 1936930.
# Manually Check App_ID 1936940.
# Manually Check App_ID 1937030.
# Manually Check App_ID 1937050.
# Manually Check App_ID 1937110.
# Manually Check App_ID 1937130.
# Manually Check App_ID 1937140.
# Manually Check App_ID 1937160.
# Manually Check App_ID 1937170.
# Manually Check App_ID 1937180.
# Manually Check App_ID 1937200.
# Manually Check App_ID 1937230.
# Manually Check App_ID 1937250.
# Manually Check App_ID 1937260.
# Manually Check App_ID 1937270.
# Manually Check App_ID 1937360.
# Manually Check App_ID 1937450.
# Manually Check App_ID 1937460.
# Manually Check App_ID 1937470.
# Manually Check App_ID 1937480.
# Manually Check App_ID 1937500.
# Manually Check App_ID 1937510.
# Manually Check App_ID 1937550.
# Manually Check App_ID 1937560.
# Manually Check App_ID 1937570.
# Manually Check App_ID 1937600.
# Manually Check App_ID 1937620.
# Manually Check App_ID 1937630.
# Manually Check App_ID 1937650.
# Manually Check App_ID 1937660.
# Manually Check App_ID 1937670.
# Manually Check App_ID 1937700.
# Manually Check App_ID 1937710.
# Manually Check App_ID 1937720.
# Manually Check App_ID 1937750.
# Manually Check App_ID 1937820.
# Manually Check App_ID 1937840.
# Manually Check App_ID 1937850.
# Manually Check App_ID 1937900.
# Manually Check App_ID 1937910.
# Manually Check App_ID 1937970.
# Manually Check App_ID 1937980.
# Manually Check App_ID 1938010.
# Manually Check App_ID 1938040.
# Manually Check App_ID 1938060.
# Manually Check App_ID 1938090.
# Manually Check App_ID 1938110.
# Manually Check App_ID 1938120.
# Manually Check App_ID 1938150.
# Manually Check App_ID 1938180.
# Manually Check App_ID 1938200.
# Manually Check App_ID 1938210.
# Manually Check App_ID 1938220.
# Manually Check App_ID 1938260.
# Manually Check App_ID 1938290.
# Manually Check App_ID 1938330.
# Manually Check App_ID 1938360.
# Manually Check App_ID 1938370.
# Manually Check App_ID 1938380.
# Manually Check App_ID 1938400.
# Manually Check App_ID 1938410.
# Manually Check App_ID 1938430.
# Manually Check App_ID 1938460.
# Manually Check App_ID 1938530.
# Manually Check App_ID 1938550.
# Manually Check App_ID 1938630.
# Manually Check App_ID 1938650.
# Manually Check App_ID 1938660.
# Manually Check App_ID 1938670.
# Manually Check App_ID 1938690.
# Manually Check App_ID 1938740.
# Manually Check App_ID 1938800.
# Manually Check App_ID 1938830.
# Manually Check App_ID 1938850.
# Manually Check App_ID 1938990.
# Manually Check App_ID 1939040.
# Manually Check App_ID 1939070.
# Manually Check App_ID 1939140.
# Manually Check App_ID 1939160.
# Manually Check App_ID 1939210.
# Manually Check App_ID 1939260.
# Manually Check App_ID 1939270.
# Manually Check App_ID 1939290.
# Manually Check App_ID 1952370.
# Manually Check App_ID 1955340.
# Manually Check App_ID 1957780.
# Manually Check App_ID 1963040.
# Manually Check App_ID 1973710.
# Manually Check App_ID 2005010.
# Manually Check App_ID 2011410.
# Manually Check App_ID 2011730.
# Manually Check App_ID 2011750.
# Manually Check App_ID 2011840.
# Manually Check App_ID 2011860.
# Manually Check App_ID 2011870.
# Manually Check App_ID 2011900.
# Manually Check App_ID 2012000.
# Manually Check App_ID 2012020.
# Manually Check App_ID 2012030.
# Manually Check App_ID 2012050.
# Manually Check App_ID 2012070.
# Manually Check App_ID 2012100.
# Manually Check App_ID 2012140.
# Manually Check App_ID 2012170.
# Manually Check App_ID 2012200.
# Manually Check App_ID 2012270.
# Manually Check App_ID 2012320.
# Manually Check App_ID 2012340.
# Manually Check App_ID 2012420.
# Manually Check App_ID 2012440.
# Manually Check App_ID 2012450.
# Manually Check App_ID 2012500.
# Manually Check App_ID 2012520.
# Manually Check App_ID 2012530.
# Manually Check App_ID 2012540.
# Manually Check App_ID 2012570.
# Manually Check App_ID 2012610.
# Manually Check App_ID 2012620.
# Manually Check App_ID 2012630.
# Manually Check App_ID 2012650.
# Manually Check App_ID 2012690.
# Manually Check App_ID 2012710.
# Manually Check App_ID 2012790.
# Manually Check App_ID 2012820.
# Manually Check App_ID 2012830.
# Manually Check App_ID 2012840.
# Manually Check App_ID 2012890.
# Manually Check App_ID 2012910.
# Manually Check App_ID 2012990.
# Manually Check App_ID 2013010.
# Manually Check App_ID 2013030.
# Manually Check App_ID 2013040.
# Manually Check App_ID 2013060.
# Manually Check App_ID 2013080.
# Manually Check App_ID 2013110.
# Manually Check App_ID 2013120.
# Manually Check App_ID 2013130.
# Manually Check App_ID 2013150.
# Manually Check App_ID 2013170.
# Manually Check App_ID 2013180.
# Manually Check App_ID 2013230.
# Manually Check App_ID 2013240.
# Manually Check App_ID 2013270.
# Manually Check App_ID 2013280.
# Manually Check App_ID 2013300.
# Manually Check App_ID 2013330.
# Manually Check App_ID 2013360.
# Manually Check App_ID 2013420.
# Manually Check App_ID 2013440.
# Manually Check App_ID 2013460.
# Manually Check App_ID 2013480.
# Manually Check App_ID 2013580.
# Manually Check App_ID 2013610.
# Manually Check App_ID 2013640.
# Manually Check App_ID 2013650.
# Manually Check App_ID 2013660.
# Manually Check App_ID 2013670.
# Manually Check App_ID 2013680.
# Manually Check App_ID 2013720.
# Manually Check App_ID 2013740.
# Manually Check App_ID 2013770.
# Manually Check App_ID 2013780.
# Manually Check App_ID 2013800.
# Manually Check App_ID 2013870.
# Manually Check App_ID 2013880.
# Manually Check App_ID 2013900.
# Manually Check App_ID 2013970.
# Manually Check App_ID 2013990.
# Manually Check App_ID 2014090.
# Manually Check App_ID 2014180.
# Manually Check App_ID 2014220.
# Manually Check App_ID 2014240.
# Manually Check App_ID 2014300.
# Manually Check App_ID 2014330.
# Manually Check App_ID 2014360.
# Manually Check App_ID 2014370.
# Manually Check App_ID 2014380.
# Manually Check App_ID 2023760.
# Manually Check App_ID 2026580.
# Manually Check App_ID 2026590.
# Manually Check App_ID 2026690.
# Manually Check App_ID 2026700.
# Manually Check App_ID 2026750.
# Manually Check App_ID 2026790.
# Manually Check App_ID 2026810.
# Manually Check App_ID 2026830.
# Manually Check App_ID 2026840.
# Manually Check App_ID 2026860.
# Manually Check App_ID 2026870.
# Manually Check App_ID 2026880.
# Manually Check App_ID 2026960.
# Manually Check App_ID 2026990.
# Manually Check App_ID 2027000.
# Manually Check App_ID 2027040.
# Manually Check App_ID 2027060.
# Manually Check App_ID 2027090.
# Manually Check App_ID 2027130.
# Manually Check App_ID 2027170.
# Manually Check App_ID 2027180.
# Manually Check App_ID 2027220.
# Manually Check App_ID 2027250.
# Manually Check App_ID 2027270.
# Manually Check App_ID 2027290.
# Manually Check App_ID 2027300.
# Manually Check App_ID 2027310.
# Manually Check App_ID 2027350.
# Manually Check App_ID 2027360.
# Manually Check App_ID 2027370.
# Manually Check App_ID 2027380.
# Manually Check App_ID 2027390.
# Manually Check App_ID 2027400.
# Manually Check App_ID 2027420.
# Manually Check App_ID 2027440.
# Manually Check App_ID 2027470.
# Manually Check App_ID 2027490.
# Manually Check App_ID 2027510.
# Manually Check App_ID 2027530.
# Manually Check App_ID 2027540.
# Manually Check App_ID 2027550.
# Manually Check App_ID 2027560.
# Manually Check App_ID 2027570.
# Manually Check App_ID 2027590.
# Manually Check App_ID 2027600.
# Manually Check App_ID 2027810.
# Manually Check App_ID 2027820.
# Manually Check App_ID 2027850.
# Manually Check App_ID 2027860.
# Manually Check App_ID 2027920.
# Manually Check App_ID 2027970.
# Manually Check App_ID 2050050.
# Manually Check App_ID 2050070.
# Manually Check App_ID 2050080.
# Manually Check App_ID 2050120.
# Manually Check App_ID 2050140.
# Manually Check App_ID 2050150.
# Manually Check App_ID 2050200.
# Manually Check App_ID 2050310.
# Manually Check App_ID 2050380.
# Manually Check App_ID 2050400.
# Manually Check App_ID 2050430.
# Manually Check App_ID 2050450.
# Manually Check App_ID 2050460.
# Manually Check App_ID 2050470.
# Manually Check App_ID 2050480.
# Manually Check App_ID 2050490.
# Manually Check App_ID 2050510.
# Manually Check App_ID 2050530.
# Manually Check App_ID 2050540.
# Manually Check App_ID 2050560.
# Manually Check App_ID 2050590.
# Manually Check App_ID 2050600.
# Manually Check App_ID 2050650.
# Manually Check App_ID 2050680.
# Manually Check App_ID 2050710.
# Manually Check App_ID 2050720.
# Manually Check App_ID 2050740.
# Manually Check App_ID 2050810.
# Manually Check App_ID 2050820.
# Manually Check App_ID 2050840.
# Manually Check App_ID 2050860.
# Manually Check App_ID 2050870.
# Manually Check App_ID 2050890.
# Manually Check App_ID 2050910.
# Manually Check App_ID 2050920.
# Manually Check App_ID 2050940.
# Manually Check App_ID 2050950.
# Manually Check App_ID 2050960.
# Manually Check App_ID 2050980.
# Manually Check App_ID 2051020.
# Manually Check App_ID 2051050.
# Manually Check App_ID 2051060.
# Manually Check App_ID 2051100.
# Manually Check App_ID 2051110.
# Manually Check App_ID 2051120.
# Manually Check App_ID 2051130.
# Manually Check App_ID 2051220.
# Manually Check App_ID 2051250.
# Manually Check App_ID 2051360.
# Manually Check App_ID 2054400.
# Manually Check App_ID 2057040.
# Manually Check App_ID 2058070.
# Manually Check App_ID 2058690.
# Manually Check App_ID 2061620.
# Manually Check App_ID 2064080.
# Manually Check App_ID 2065090.
# Manually Check App_ID 2065100.
# Manually Check App_ID 2065110.
# Manually Check App_ID 2065140.
# Manually Check App_ID 2065180.
# Manually Check App_ID 2065200.
# Manually Check App_ID 2065260.
# Manually Check App_ID 2065330.
# Manually Check App_ID 2065390.
# Manually Check App_ID 2065420.
# Manually Check App_ID 2065510.
# Manually Check App_ID 2065520.
# Manually Check App_ID 2065560.
# Manually Check App_ID 2065570.
# Manually Check App_ID 2065580.
# Manually Check App_ID 2065610.
# Manually Check App_ID 2065630.
# Manually Check App_ID 2065650.
# Manually Check App_ID 2065690.
# Manually Check App_ID 2065750.
# Manually Check App_ID 2065780.
# Manually Check App_ID 2065800.
# Manually Check App_ID 2065810.
# Manually Check App_ID 2065820.
# Manually Check App_ID 2065830.
# Manually Check App_ID 2065840.
# Manually Check App_ID 2065860.
# Manually Check App_ID 2065910.
# Manually Check App_ID 2065920.
# Manually Check App_ID 2065990.
# Manually Check App_ID 2066010.
# Manually Check App_ID 2066020.
# Manually Check App_ID 2066030.
# Manually Check App_ID 2066110.
# Manually Check App_ID 2066130.
# Manually Check App_ID 2066170.
# Manually Check App_ID 2066200.
# Manually Check App_ID 2066210.
# Manually Check App_ID 2066220.
# Manually Check App_ID 2066240.
# Manually Check App_ID 2066250.
# Manually Check App_ID 2066270.
# Manually Check App_ID 2066300.
# Manually Check App_ID 2066320.
# Manually Check App_ID 2066330.
# Manually Check App_ID 2066360.
# Manually Check App_ID 2066390.
# Manually Check App_ID 2066420.
# Manually Check App_ID 2066430.
# Manually Check App_ID 2066460.
# Manually Check App_ID 2066480.
# Manually Check App_ID 2066490.
# Manually Check App_ID 2066530.
# Manually Check App_ID 2066540.
# Manually Check App_ID 2066550.
# Manually Check App_ID 2066610.
# Manually Check App_ID 2066690.
# Manually Check App_ID 2066780.
# Manually Check App_ID 2066870.
# Manually Check App_ID 2066920.
# Manually Check App_ID 2066940.
# Manually Check App_ID 2066950.
# Manually Check App_ID 2066960.
# Manually Check App_ID 2067000.
# Manually Check App_ID 2067100.
# Manually Check App_ID 2067120.
# Manually Check App_ID 2067140.
# Manually Check App_ID 2067150.
# Manually Check App_ID 2067170.
# Manually Check App_ID 2067200.
# Manually Check App_ID 2067220.
# Manually Check App_ID 2067240.
# Manually Check App_ID 2067260.
# Manually Check App_ID 2067270.
# Manually Check App_ID 2067280.
# Manually Check App_ID 2067300.
# Manually Check App_ID 2067330.
# Manually Check App_ID 2067340.
# Manually Check App_ID 2067440.
# Manually Check App_ID 2067470.
# Manually Check App_ID 2067520.
# Manually Check App_ID 2067570.
# Manually Check App_ID 2067590.
# Manually Check App_ID 2067670.
# Manually Check App_ID 2067700.
# Manually Check App_ID 2067720.
# Manually Check App_ID 2067730.
# Manually Check App_ID 2067750.
# Manually Check App_ID 2067760.
# Manually Check App_ID 2067780.
# Manually Check App_ID 2067790.
# Manually Check App_ID 2067830.
# Manually Check App_ID 2067840.
# Manually Check App_ID 2067850.
# Manually Check App_ID 2067900.
# Manually Check App_ID 2067910.
# Manually Check App_ID 2067920.
# Manually Check App_ID 2067930.
# Manually Check App_ID 2067940.
# Manually Check App_ID 2067950.
# Manually Check App_ID 2067970.
# Manually Check App_ID 2068030.
# Manually Check App_ID 2068040.
# Manually Check App_ID 2068050.
# Manually Check App_ID 2068090.
# Manually Check App_ID 2068120.
# Manually Check App_ID 2070630.
# Manually Check App_ID 2070980.
# Manually Check App_ID 2071560.
# Manually Check App_ID 2075340.
# Manually Check App_ID 2093970.
# Manually Check App_ID 2096030.
# Manually Check App_ID 2111400.
# Manually Check App_ID 2111860.
# Manually Check App_ID 2111890.
# Manually Check App_ID 2113120.
# Manually Check App_ID 2113220.
# Manually Check App_ID 2114740.
# Manually Check App_ID 2114970.
# Manually Check App_ID 2115390.
# Manually Check App_ID 2115590.
# Manually Check App_ID 2115850.
# Manually Check App_ID 2116780.
# Manually Check App_ID 2117420.
# Manually Check App_ID 2118370.
# Manually Check App_ID 2118540.
# Manually Check App_ID 2119590.
# Manually Check App_ID 2120060.
# Manually Check App_ID 2120070.
# Manually Check App_ID 2120270.
# Manually Check App_ID 2120840.
# Manually Check App_ID 2120900.
# Manually Check App_ID 2121610.
# Manually Check App_ID 2121910.
# Manually Check App_ID 2123770.
# Manually Check App_ID 2123990.
# Manually Check App_ID 2124090.
# Manually Check App_ID 2124840.
# Manually Check App_ID 2125910.
# Manually Check App_ID 2125920.
# Manually Check App_ID 2125930.
# Manually Check App_ID 2125950.
# Manually Check App_ID 2126000.
# Manually Check App_ID 2126010.
# Manually Check App_ID 2126020.
# Manually Check App_ID 2126120.
# Manually Check App_ID 2126150.
# Manually Check App_ID 2126250.
# Manually Check App_ID 2126270.
# Manually Check App_ID 2126300.
# Manually Check App_ID 2126310.
# Manually Check App_ID 2126340.
# Manually Check App_ID 2126370.
# Manually Check App_ID 2126380.
# Manually Check App_ID 2126400.
# Manually Check App_ID 2126500.
# Manually Check App_ID 2126550.
# Manually Check App_ID 2126580.
# Manually Check App_ID 2126590.
# Manually Check App_ID 2126600.
# Manually Check App_ID 2126620.
# Manually Check App_ID 2126630.
# Manually Check App_ID 2126650.
# Manually Check App_ID 2126680.
# Manually Check App_ID 2126700.
# Manually Check App_ID 2126760.
# Manually Check App_ID 2126790.
# Manually Check App_ID 2126810.
# Manually Check App_ID 2126830.
# Manually Check App_ID 2126840.
# Manually Check App_ID 2126870.
# Manually Check App_ID 2126940.
# Manually Check App_ID 2126960.
# Manually Check App_ID 2126970.
# Manually Check App_ID 2126980.
# Manually Check App_ID 2126990.
# Manually Check App_ID 2127010.
# Manually Check App_ID 2127080.
# Manually Check App_ID 2127100.
# Manually Check App_ID 2127160.
# Manually Check App_ID 2127190.
# Manually Check App_ID 2127230.
# Manually Check App_ID 2127300.
# Manually Check App_ID 2127310.
# Manually Check App_ID 2127330.
# Manually Check App_ID 2127430.
# Manually Check App_ID 2127440.
# Manually Check App_ID 2127550.
# Manually Check App_ID 2127590.
# Manually Check App_ID 2127610.
# Manually Check App_ID 2127660.
# Manually Check App_ID 2127700.
# Manually Check App_ID 2127720.
# Manually Check App_ID 2127750.
# Manually Check App_ID 2127800.
# Manually Check App_ID 2127810.
# Manually Check App_ID 2127820.
# Manually Check App_ID 2127860.
# Manually Check App_ID 2127920.
# Manually Check App_ID 2127930.
# Manually Check App_ID 2127990.
# Manually Check App_ID 2128010.
# Manually Check App_ID 2128020.
# Manually Check App_ID 2128030.
# Manually Check App_ID 2128040.
# Manually Check App_ID 2128050.
# Manually Check App_ID 2128120.
# Manually Check App_ID 2128130.
# Manually Check App_ID 2128140.
# Manually Check App_ID 2128170.
# Manually Check App_ID 2128220.
# Manually Check App_ID 2128230.
# Manually Check App_ID 2128270.
# Manually Check App_ID 2128290.
# Manually Check App_ID 2128300.
# Manually Check App_ID 2128310.
# Manually Check App_ID 2128340.
# Manually Check App_ID 2128360.
# Manually Check App_ID 2128390.
# Manually Check App_ID 2128400.
# Manually Check App_ID 2128410.
# Manually Check App_ID 2128440.
# Manually Check App_ID 2128450.
# Manually Check App_ID 2141470.
# Manually Check App_ID 2141490.
# Manually Check App_ID 2141540.
# Manually Check App_ID 2141550.
# Manually Check App_ID 2141600.
# Manually Check App_ID 2141640.
# Manually Check App_ID 2141650.
# Manually Check App_ID 2141690.
# Manually Check App_ID 2141710.
# Manually Check App_ID 2141720.
# Manually Check App_ID 2141730.
# Manually Check App_ID 2141740.
# Manually Check App_ID 2141780.
# Manually Check App_ID 2141810.
# Manually Check App_ID 2141820.
# Manually Check App_ID 2141850.
# Manually Check App_ID 2141900.
# Manually Check App_ID 2141910.
# Manually Check App_ID 2141990.
# Manually Check App_ID 2142020.
# Manually Check App_ID 2142030.
# Manually Check App_ID 2142040.
# Manually Check App_ID 2142100.
# Manually Check App_ID 2142110.
# Manually Check App_ID 2142140.
# Manually Check App_ID 2142150.
# Manually Check App_ID 2142160.
# Manually Check App_ID 2142170.
# Manually Check App_ID 2142210.
# Manually Check App_ID 2142220.
# Manually Check App_ID 2142280.
# Manually Check App_ID 2142290.
# Manually Check App_ID 2142370.
# Manually Check App_ID 2142400.
# Manually Check App_ID 2142430.
# Manually Check App_ID 2142440.
# Manually Check App_ID 2142450.
# Manually Check App_ID 2142460.
# Manually Check App_ID 2142470.
# Manually Check App_ID 2142530.
# Manually Check App_ID 2142540.
# Manually Check App_ID 2142610.
# Manually Check App_ID 2142630.
# Manually Check App_ID 2142710.
# Manually Check App_ID 2142780.
# ...
# Manually Check App_ID 2306390.
# Manually Check App_ID 2306400.
# Manually Check App_ID 2306450.
# Manually Check App_ID 2306480.
# Manually Check App_ID 2306580.
# Manually Check App_ID 2306590.
# Manually Check App_ID 2306630.
# Manually Check App_ID 2306670.
# Manually Check App_ID 2306710.
# Manually Check App_ID 2306730.
# Manually Check App_ID 2306850.
# Manually Check App_ID 2306860.
# Manually Check App_ID 2306880.
# Manually Check App_ID 2306930.
# Manually Check App_ID 2306960.
# Manually Check App_ID 2307010.
# Manually Check App_ID 2307020.
# Manually Check App_ID 2307050.
# Manually Check App_ID 2307060.
# Manually Check App_ID 2307070.
# Manually Check App_ID 2307080.
# Manually Check App_ID 2307090.
# Manually Check App_ID 2307100.
# Manually Check App_ID 2307120.
# Manually Check App_ID 2307150.
# Manually Check App_ID 2307160.
# Manually Check App_ID 2307180.
# Manually Check App_ID 2307210.
# Manually Check App_ID 2307220.
# Manually Check App_ID 2307250.
# Manually Check App_ID 2307320.
# Manually Check App_ID 2307330.
# Manually Check App_ID 2307370.
# Manually Check App_ID 2307410.
# Manually Check App_ID 2307420.
# Manually Check App_ID 2307430.
# Manually Check App_ID 2307450.
# Manually Check App_ID 2307460.
# Manually Check App_ID 2307490.
# Manually Check App_ID 2307520.
# Manually Check App_ID 2307550.
# Manually Check App_ID 2307570.
# Manually Check App_ID 2307580.
# Manually Check App_ID 2307610.
# Manually Check App_ID 2307630.
# Manually Check App_ID 2307650.
# Manually Check App_ID 2307690.
# Manually Check App_ID 2307760.
# Manually Check App_ID 2307790.
# Manually Check App_ID 2307830.
# Manually Check App_ID 2307860.
# Manually Check App_ID 2307880.
# Manually Check App_ID 2307890.
# Manually Check App_ID 2307910.
# Manually Check App_ID 2307950.
# Manually Check App_ID 2308040.
# Manually Check App_ID 2308120.
# Manually Check App_ID 2308170.
# Manually Check App_ID 2308200.
# Manually Check App_ID 2308220.
# Manually Check App_ID 2308340.
# Manually Check App_ID 2308360.
# Manually Check App_ID 2308400.
# Manually Check App_ID 2308430.
# Manually Check App_ID 2308460.
# Manually Check App_ID 2308470.
# Manually Check App_ID 2308520.
# Manually Check App_ID 2308540.
# Manually Check App_ID 2308550.
# Manually Check App_ID 2308580.
# Manually Check App_ID 2308650.
# Manually Check App_ID 2308770.
# Manually Check App_ID 2308790.
# Manually Check App_ID 2308820.
# Manually Check App_ID 2308850.
# Manually Check App_ID 2308880.
# Manually Check App_ID 2308890.
# Manually Check App_ID 2308920.
# Manually Check App_ID 2308940.
# Manually Check App_ID 2308960.
# Manually Check App_ID 2309010.
# Manually Check App_ID 2309030.
# Manually Check App_ID 2309040.
# Manually Check App_ID 2309060.
# Manually Check App_ID 2309090.
# Manually Check App_ID 2309120.
# Manually Check App_ID 2309230.
# Manually Check App_ID 2309250.
# Manually Check App_ID 2309270.
# Manually Check App_ID 2309280.
# Manually Check App_ID 2312030.
# Manually Check App_ID 2325860.
# Manually Check App_ID 2326070.
# Manually Check App_ID 2326650.
# Manually Check App_ID 2326670.
# Manually Check App_ID 2326690.
# Manually Check App_ID 2326710.
# Manually Check App_ID 2326720.
# Manually Check App_ID 2326730.
# Manually Check App_ID 2326740.
# Manually Check App_ID 2326780.
# Manually Check App_ID 2327260.
# Manually Check App_ID 2327480.
# Manually Check App_ID 2327660.
# Manually Check App_ID 2327780.
# Manually Check App_ID 2327940.
# Manually Check App_ID 2327980.
# Manually Check App_ID 2328380.
# Manually Check App_ID 2328980.
# Manually Check App_ID 2329490.
# Manually Check App_ID 2330260.
# Manually Check App_ID 2330970.
# Manually Check App_ID 2331750.
# Manually Check App_ID 2331950.
# Manually Check App_ID 2332120.
# Manually Check App_ID 2332660.
# Manually Check App_ID 2332810.
# Manually Check App_ID 2334250.
# Manually Check App_ID 2334480.
# Manually Check App_ID 2335590.
# Manually Check App_ID 2336090.
# Manually Check App_ID 2336160.
# Manually Check App_ID 2336180.
# Manually Check App_ID 2336200.
# Manually Check App_ID 2336590.
# Manually Check App_ID 2337140.
# Manually Check App_ID 2337280.
# Manually Check App_ID 2337630.
# Manually Check App_ID 2337890.
# Manually Check App_ID 2338290.
# Manually Check App_ID 2339310.
# Manually Check App_ID 2339430.
# Manually Check App_ID 2339690.
# Manually Check App_ID 2340010.
# Manually Check App_ID 2340800.
# Manually Check App_ID 2340910.
# Manually Check App_ID 2341540.
# Manually Check App_ID 2341600.
# Manually Check App_ID 2341710.
# Manually Check App_ID 2342400.
# Manually Check App_ID 2343410.
# Manually Check App_ID 2343480.
# Manually Check App_ID 2343570.
# Manually Check App_ID 2343600.
# Manually Check App_ID 2343610.
# Manually Check App_ID 2343630.
# Manually Check App_ID 2343660.
# Manually Check App_ID 2343720.
# Manually Check App_ID 2343730.
# Manually Check App_ID 2343750.
# Manually Check App_ID 2343780.
# Manually Check App_ID 2343810.
# Manually Check App_ID 2343850.
# Manually Check App_ID 2343860.
# Manually Check App_ID 2343910.
# Manually Check App_ID 2343920.
# Manually Check App_ID 2343930.
# Manually Check App_ID 2343960.
# Manually Check App_ID 2343990.
# Manually Check App_ID 2344020.
# Manually Check App_ID 2344030.
# Manually Check App_ID 2344040.
# Manually Check App_ID 2344060.
# Manually Check App_ID 2344100.
# Manually Check App_ID 2344130.
# Manually Check App_ID 2344170.
# Manually Check App_ID 2344190.
# Manually Check App_ID 2344240.
# Manually Check App_ID 2344350.
# Manually Check App_ID 2344390.
# Manually Check App_ID 2344450.
# Manually Check App_ID 2344480.
# Manually Check App_ID 2344550.
# Manually Check App_ID 2344590.
# Manually Check App_ID 2344630.
# Manually Check App_ID 2344650.
# Manually Check App_ID 2344680.
# Manually Check App_ID 2344700.
# Manually Check App_ID 2344800.
# Manually Check App_ID 2344820.
# Manually Check App_ID 2344890.
# Manually Check App_ID 2344900.
# Manually Check App_ID 2344920.
# Manually Check App_ID 2344950.
# Manually Check App_ID 2344980.
# Manually Check App_ID 2344990.
# Manually Check App_ID 2345010.
# Manually Check App_ID 2345020.
# Manually Check App_ID 2345040.
# Manually Check App_ID 2345050.
# Manually Check App_ID 2345060.
# Manually Check App_ID 2345090.
# Manually Check App_ID 2345110.
# Manually Check App_ID 2345140.
# Manually Check App_ID 2345200.
# Manually Check App_ID 2345230.
# Manually Check App_ID 2345250.
# Manually Check App_ID 2345290.
# Manually Check App_ID 2345300.
# Manually Check App_ID 2345360.
# Manually Check App_ID 2345370.
# Manually Check App_ID 2349490.
# Manually Check App_ID 2379390.
# Manually Check App_ID 2386160.
# Manually Check App_ID 2386840.
# Manually Check App_ID 2390030.
# Manually Check App_ID 2394740.
# Manually Check App_ID 2394780.
# Manually Check App_ID 2394810.
# Manually Check App_ID 2394830.
# Manually Check App_ID 2394870.
# Manually Check App_ID 2394930.
# Manually Check App_ID 2394980.
# Manually Check App_ID 2395080.
# Manually Check App_ID 2395120.
# Manually Check App_ID 2395190.
# Manually Check App_ID 2395230.
# Manually Check App_ID 2395260.
# Manually Check App_ID 2395280.
# Manually Check App_ID 2395290.
# Manually Check App_ID 2395310.
# Manually Check App_ID 2395360.
# Manually Check App_ID 2395370.
# Manually Check App_ID 2395380.
# Manually Check App_ID 2395400.
# Manually Check App_ID 2395410.
# Manually Check App_ID 2395450.
# Manually Check App_ID 2395510.
# Manually Check App_ID 2395530.
# Manually Check App_ID 2395580.
# Manually Check App_ID 2395620.
# Manually Check App_ID 2395630.
# Manually Check App_ID 2395640.
# Manually Check App_ID 2395680.
# Manually Check App_ID 2395730.
# Manually Check App_ID 2395760.
# Manually Check App_ID 2395790.
# Manually Check App_ID 2395800.
# Manually Check App_ID 2395810.
# Manually Check App_ID 2395820.
# Manually Check App_ID 2395840.
# Manually Check App_ID 2395940.
# Manually Check App_ID 2396000.
# Manually Check App_ID 2396120.
# Manually Check App_ID 2396210.
# Manually Check App_ID 2396320.
# Manually Check App_ID 2396340.
# Manually Check App_ID 2396350.
# Manually Check App_ID 2396360.
# Manually Check App_ID 2396380.
# Manually Check App_ID 2396450.
# Manually Check App_ID 2396530.
# Manually Check App_ID 2396620.
# Manually Check App_ID 2396640.
# Manually Check App_ID 2396680.
# Manually Check App_ID 2396800.
# Manually Check App_ID 2396860.
# Manually Check App_ID 2397010.
# Manually Check App_ID 2397020.
# Manually Check App_ID 2397040.
# Manually Check App_ID 2397080.
# Manually Check App_ID 2397230.
# Manually Check App_ID 2397270.
# Manually Check App_ID 2397350.
# Manually Check App_ID 2397370.
# Manually Check App_ID 2397380.
# Manually Check App_ID 2397400.
# Manually Check App_ID 2397500.
# Manually Check App_ID 2397510.
# Manually Check App_ID 2397540.
# Manually Check App_ID 2397610.
# Manually Check App_ID 2397690.
# Manually Check App_ID 2397700.
# Manually Check App_ID 2397860.
# Manually Check App_ID 2397930.
# Manually Check App_ID 2397980.
# Manually Check App_ID 2398000.
# Manually Check App_ID 2398010.
# Manually Check App_ID 2398020.
# Manually Check App_ID 2398130.
# Manually Check App_ID 2398190.
# Manually Check App_ID 2398200.
# Manually Check App_ID 2398220.
# Manually Check App_ID 2398240.
# Manually Check App_ID 2398300.
# Manually Check App_ID 2398310.
# Manually Check App_ID 2398350.
# Manually Check App_ID 2398410.
# Manually Check App_ID 2398500.
# Manually Check App_ID 2398530.
# Manually Check App_ID 2398640.
# Manually Check App_ID 2398900.
# Manually Check App_ID 2405020.
# Manually Check App_ID 2408870.
# Manually Check App_ID 2414210.
# Manually Check App_ID 2414240.
# Manually Check App_ID 2414260.
# Manually Check App_ID 2414320.
# Manually Check App_ID 2414340.
# Manually Check App_ID 2414350.
# Manually Check App_ID 2414360.
# Manually Check App_ID 2414530.
# Manually Check App_ID 2414640.
# Manually Check App_ID 2414690.
# Manually Check App_ID 2414710.
# Manually Check App_ID 2414730.
# Manually Check App_ID 2414810.
# Manually Check App_ID 2414920.
# Manually Check App_ID 2414950.
# Manually Check App_ID 2415120.
# Manually Check App_ID 2415180.
# Manually Check App_ID 2415430.
# Manually Check App_ID 2415520.
# Manually Check App_ID 2415540.
# Manually Check App_ID 2415570.
# Manually Check App_ID 2415600.
# Manually Check App_ID 2415630.
# Manually Check App_ID 2415640.
# Manually Check App_ID 2415660.
# Manually Check App_ID 2415670.
# Manually Check App_ID 2415740.
# Manually Check App_ID 2415770.
# Manually Check App_ID 2415830.
# Manually Check App_ID 2415930.
# Manually Check App_ID 2415950.
# Manually Check App_ID 2415960.
# Manually Check App_ID 2415980.
# Manually Check App_ID 2416000.
# Manually Check App_ID 2416030.
# Manually Check App_ID 2416060.
# Manually Check App_ID 2416110.
# Manually Check App_ID 2416150.
# Manually Check App_ID 2416240.
# Manually Check App_ID 2416250.
# Manually Check App_ID 2416260.
# Manually Check App_ID 2416300.
# Manually Check App_ID 2416370.
# Manually Check App_ID 2416460.
# Manually Check App_ID 2416480.
# Manually Check App_ID 2416550.
# Manually Check App_ID 2416580.
# Manually Check App_ID 2416720.
# Manually Check App_ID 2416740.
# Manually Check App_ID 2416770.
# Manually Check App_ID 2416790.
# Manually Check App_ID 2416820.
# Manually Check App_ID 2416840.
# Manually Check App_ID 2416860.
# Manually Check App_ID 2416880.
# Manually Check App_ID 2416890.
# Manually Check App_ID 2416920.
# Manually Check App_ID 2416970.
# Manually Check App_ID 2417060.
# Manually Check App_ID 2417090.
# Manually Check App_ID 2417160.
# Manually Check App_ID 2417180.
# Manually Check App_ID 2417240.
# Manually Check App_ID 2417250.
# Manually Check App_ID 2417300.
# Manually Check App_ID 2417340.
# Manually Check App_ID 2417400.
# Manually Check App_ID 2417490.
# Manually Check App_ID 2417510.
# Manually Check App_ID 2417520.
# Manually Check App_ID 2417570.
# Manually Check App_ID 2417620.
# Manually Check App_ID 2417640.
# Manually Check App_ID 2417650.
# Manually Check App_ID 2417700.
# Manually Check App_ID 2426900.
# Manually Check App_ID 2427960.
# Manually Check App_ID 2430810.
# Manually Check App_ID 2431360.
# Manually Check App_ID 2434590.
# Manually Check App_ID 2437160.
# Manually Check App_ID 2437370.
# Manually Check App_ID 2437400.
# Manually Check App_ID 2437430.
# Manually Check App_ID 2437500.
# Manually Check App_ID 2437560.
# Manually Check App_ID 2437680.
# Manually Check App_ID 2437700.
# Manually Check App_ID 2437760.
# Manually Check App_ID 2437780.
# Manually Check App_ID 2437890.
# Manually Check App_ID 2437910.
# Manually Check App_ID 2437980.
# Manually Check App_ID 2437990.
# Manually Check App_ID 2438020.
# Manually Check App_ID 2438060.
# Manually Check App_ID 2438330.
# Manually Check App_ID 2438340.
# Manually Check App_ID 2438380.
# Manually Check App_ID 2438520.
# Manually Check App_ID 2438540.
# Manually Check App_ID 2438590.
# Manually Check App_ID 2438680.
# Manually Check App_ID 2438760.
# Manually Check App_ID 2439000.
# Manually Check App_ID 2439010.
# Manually Check App_ID 2439020.
# Manually Check App_ID 2439120.
# Manually Check App_ID 2439180.
# Manually Check App_ID 2439400.
# Manually Check App_ID 2439430.
# Manually Check App_ID 2439450.
# Manually Check App_ID 2439550.
# Manually Check App_ID 2439640.
# Manually Check App_ID 2439660.
# Manually Check App_ID 2439710.
# Manually Check App_ID 2439730.
# Manually Check App_ID 2439800.
# Manually Check App_ID 2439870.
# Manually Check App_ID 2439900.
# Manually Check App_ID 2439910.
# Manually Check App_ID 2439920.
# Manually Check App_ID 2439930.
# Manually Check App_ID 2439940.
# Manually Check App_ID 2440180.
# Manually Check App_ID 2440200.
# Manually Check App_ID 2440270.
# Manually Check App_ID 2440320.
# Manually Check App_ID 2440510.
# Manually Check App_ID 2440610.
# Manually Check App_ID 2440730.
# Manually Check App_ID 2440800.
# Manually Check App_ID 2440810.
# Manually Check App_ID 2440900.
# Manually Check App_ID 2440970.
# Manually Check App_ID 2441070.
# Manually Check App_ID 2441090.
# Manually Check App_ID 2441120.
# Manually Check App_ID 2441190.
# Manually Check App_ID 2441200.
# Manually Check App_ID 2441240.
# Manually Check App_ID 2441250.
# Manually Check App_ID 2441270.
# Manually Check App_ID 2441300.
# Manually Check App_ID 2441440.
# Manually Check App_ID 2441530.
# Manually Check App_ID 2441610.
# Manually Check App_ID 2444000.
# Manually Check App_ID 2444840.
# Manually Check App_ID 2445390.
# Manually Check App_ID 2446500.
# Manually Check App_ID 2447010.
# Manually Check App_ID 2448710.
# Manually Check App_ID 2451740.
# Manually Check App_ID 2453980.
# Manually Check App_ID 2454350.
# Manually Check App_ID 2454740.
# Manually Check App_ID 2460450.
# Manually Check App_ID 2460680.
# Manually Check App_ID 2465780.
# Manually Check App_ID 2466010.
# Manually Check App_ID 2466230.
# Manually Check App_ID 2466280.
# Manually Check App_ID 2466310.
# Manually Check App_ID 2466320.
# Manually Check App_ID 2466450.
# Manually Check App_ID 2466500.
# Manually Check App_ID 2466510.
# Manually Check App_ID 2466550.
# Manually Check App_ID 2466660.
# Manually Check App_ID 2466740.
# Manually Check App_ID 2466750.
# Manually Check App_ID 2466830.
# Manually Check App_ID 2466850.
# Manually Check App_ID 2466870.
# Manually Check App_ID 2466880.
# Manually Check App_ID 2466890.
# Manually Check App_ID 2466990.
# Manually Check App_ID 2467070.
# Manually Check App_ID 2467090.
# Manually Check App_ID 2467180.
# Manually Check App_ID 2467370.
# Manually Check App_ID 2467570.
# Manually Check App_ID 2467630.
# Manually Check App_ID 2467650.
# Manually Check App_ID 2467730.
# Manually Check App_ID 2467800.
# Manually Check App_ID 2467910.
# Manually Check App_ID 2467920.
# Manually Check App_ID 2467960.
# Manually Check App_ID 2468080.
# Manually Check App_ID 2468450.
# Manually Check App_ID 2468730.
# Manually Check App_ID 2468800.
# Manually Check App_ID 2468900.
# Manually Check App_ID 2468910.
# Manually Check App_ID 2468990.
# Manually Check App_ID 2469360.
# Manually Check App_ID 2469550.
# Manually Check App_ID 2469610.
# Manually Check App_ID 2469740.
# Manually Check App_ID 2469900.
# Manually Check App_ID 2469950.
# Manually Check App_ID 2470130.
# Manually Check App_ID 2470290.
# Manually Check App_ID 2470360.
# Manually Check App_ID 2470920.
# Manually Check App_ID 2471250.
# Manually Check App_ID 2471560.
# Manually Check App_ID 2471600.
# Manually Check App_ID 2471620.
# Manually Check App_ID 2471630.
# Manually Check App_ID 2471780.
# Manually Check App_ID 2471900.
# Manually Check App_ID 2471950.
# Manually Check App_ID 2472230.
# Manually Check App_ID 2472260.
# Manually Check App_ID 2472270.
# Manually Check App_ID 2472500.
# Manually Check App_ID 2472840.
# Manually Check App_ID 2473150.
# Manually Check App_ID 2473690.

# %%
df
# Out:
#                                           Game  Steam_AppID  Minimum_age  \
# 0                               Counter-Strike           10            0
# 1                        Team Fortress Classic           20            0
# 2                                Day of Defeat           30            0
# 3                           Deathmatch Classic           40            0
# 4                    Half-Life: Opposing Force           50            0
# ...                                        ...          ...          ...
# 11273                              GoldenMiner      2472270            0
# 11274                   Dose Response Playtest      2472500            0
# 11275                          Ducks Can Drive      2472840            0
# 11276              Cards We're Dealt: Prologue      2473150            0
# 11277  Professor Goodboi's Ballistics Playtest      2473690            0
#
#        Free                                     About_the_Game  \
# 0         0  Play the world's number 1 online action game. ...
# 1         0  One of the most popular online action games of...
# 2         0  Enlist in an intense brand of Axis vs. Allied ...
# 3         0  Enjoy fast-paced multiplayer gaming with Death...
# 4         0  Return to the Black Mesa Research Facility as ...
# ...     ...                                                ...
# 11273     0  This is a puzzle game. In this game, gold coin...
# 11274     0                                                NaN
# 11275     1  Ducks like to race, even in their own cars! Ea...
# 11276     1  <h2 class="bb_tag">Cards We're Dealt: Prologue...
# 11277     0                                                NaN
#
#              Developers    Publishers  Windows_Support  Mac_Support  \
# 0                 Valve         Valve                1            1
# 1                 Valve         Valve                1            1
# 2                 Valve         Valve                1            1
# 3                 Valve         Valve                1            1
# 4      Gearbox Software         Valve                1            1
# ...                 ...           ...              ...          ...
# 11273       GoldenMiner   GoldenMiner                1            0
# 11274               NaN           NaN                1            0
# 11275       Joseph Cook   Joseph Cook                1            0
# 11276      Cole Chittim  Cole Chittim                1            1
# 11277               NaN           NaN                1            0
#
#        Linux_Support  ...  Original_Price  \
# 0                  1  ...            8.19
# 1                  1  ...            3.99
# 2                  1  ...            3.99
# 3                  1  ...            3.99
# 4                  1  ...            3.99
# ...              ...  ...             ...
# 11273              0  ...            0.00
# 11274              0  ...            0.00
# 11275              1  ...            0.00
# 11276              1  ...            0.00
# 11277              0  ...            0.00
#
#                                   categories_Description  genres_Description  \
# 0      Multi-player, PvP, Online PvP, Shared/Split Sc...              Action
# 1      Multi-player, PvP, Online PvP, Shared/Split Sc...              Action
# 2                 Multi-player, Valve Anti-Cheat enabled              Action
# 3      Multi-player, PvP, Online PvP, Shared/Split Sc...              Action
# 4      Single-player, Multi-player, Valve Anti-Cheat ...              Action
# ...                                                  ...                 ...
# 11273                                      Single-player  Casual, Simulation
# 11274                                                NaN                 NaN
# 11275  Single-player, Multi-player, PvP, Online PvP, ...              Racing
# 11276  Single-player, Full controller support, Steam ...       Action, Indie
# 11277                                                NaN                 NaN
#
#        Is_Subscription  Positive_Reviews  Negative_Reviews  \
# 0                    0            214780              5476
# 1                    0              6362               980
# 2                    0              5629               621
# 3                    0              2179               482
# 4                    0             17044               864
# ...                ...               ...               ...
# 11273                0                 0                 0
# 11274                0                 0                 0
# 11275                0                 0                 0
# 11276                0                 0                 0
# 11277                0                 0                 0
#
#        Peak_Players_Yesterday  Total_reviews  Peak_Players_All_Time  \
# 0                       11739         220256                   None
# 1                          72           7342                   None
# 2                          94           6250                   None
# 3                           6           2661                   None
# 4                         128          17908                   None
# ...                       ...            ...                    ...
# 11273                       0              0                   None
# 11274                       0              0                   None
# 11275                       0              0                   None
# 11276                       0              0                   None
# 11277                       0              0                   None
#
#       Peak_Players_all_Time
# 0                   319,586
# 1                     1,897
# 2                     7,758
# 3                       628
# 4                       619
# ...                     ...
# 11273                  None
# 11274                  None
# 11275                  None
# 11276                  None
# 11277                  None
#
# [11278 rows x 28 columns]

# %%
# Remove commas
df['Peak_Players_all_Time'] = df['Peak_Players_all_Time'].str.replace(',', '')

# %%
# Convert 'None' to NaN (missing value)
df['Peak_Players_all_Time'] = df['Peak_Players_all_Time'].replace('None', np.nan)

# Convert non-finite values to NaN
df['Peak_Players_all_Time'] = df['Peak_Players_all_Time'].replace([np.inf, -np.inf], np.nan)

# Convert the column to int
df['Peak_Players_all_Time'] = df['Peak_Players_all_Time'].astype(float).astype('Int64')

# %% [markdown]
# ## All data gathered

# %%
df.to_excel('Data/steam_data_final.xlsx')
